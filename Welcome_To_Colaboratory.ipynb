# %% [markdown]
# <a href="https://colab.research.google.com/github/vinodrocks300/Gemini/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap

import google.generativeai as genai

#Used to securely store yout API key
from google.colab import userdata

from IPython.display import display
from IPython.display import Markdown

# %%
#Or use `os.getenv('GOOGLE_API_KEY') `to fetch an environment variable.
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
# %%time
response = model.generate_content("Explain the difference between Outsystems 11 and ODC?")
# Out:
# CPU times: user 158 ms, sys: 14.2 ms, total: 172 ms
# Wall time: 10.3 s

# %%
Markdown(response.text)
# Out:
# OutSystems 11 and ODC (OutSystems Development Cloud) are both development platforms offered by OutSystems. However, there are several key differences between the two:
#
# **Deployment and Scalability:**
#
# * **OutSystems 11:** OutSystems 11 is an on-premises platform that requires developers to install and maintain the platform on their own servers. It allows for more control over the platform and customization, but it also requires more technical expertise and resources to manage. Scalability is limited to the capacity of the on-premises infrastructure.
# * **ODC:** ODC is a cloud-based platform hosted and managed by OutSystems. It eliminates the need for developers to set up and maintain the platform. ODC handles scalability by automatically scaling resources as needed, ensuring that applications can handle increasing traffic or user loads.
#
# **Licensing and Pricing:**
#
# ...

# %%
response.prompt_feedback
# Out:
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %%
import PIL.Image

img = PIL.Image.open('EE Logo.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=342x360>

# %%
model = genai.GenerativeModel('gemini-pro-vision')

# %%
response = model.generate_content(img)
Markdown(response.text)
# Out:
#  The image shows a group of people of different colors holding hands in a circle. This image represents teamwork and unity. The different colors of the people represent diversity and inclusion. The circle represents the strength of the group and the power of working together.

# %%
model = genai.GenerativeModel('gemini-pro')
chat = model.start_chat(history=[])
chat

# %%
response = chat.send_message("What are the usecases for LLMs?")
Markdown(response.text)
# Out:
# 1. **Natural Language Processing (NLP):**
#    - Text Summarization: LLMs can create concise summaries of text documents, articles, or research papers, making it easier for users to quickly understand the key points.
#    - Machine Translation: LLMs can translate text from one language to another, enabling global communication and understanding.
#    - Question Answering: LLMs can answer questions about a wide range of topics, providing useful information to users in a conversational manner.
#    - Chatbots and Virtual Assistants: LLMs power chatbots and virtual assistants that can engage in natural language conversations with users, providing information, answering queries, and performing various tasks.
#
# 2. **Content Creation:**
#    - Creative Writing: LLMs can generate creative text, such as stories, poems, and scripts, demonstrating their ability to produce unique and engaging content.
# ...

# %%
chat.history
# Out:
# [parts {
#    text: "What are the usecases for LLMs?"
#  }
#  role: "user",
#  parts {
# ...

# %%
response = chat.send_message("Okay. can you explaim more about Information Retrieval using LLms")
Markdown(response.text)
# Out:
# Information Retrieval (IR) using Large Language Models (LLMs) involves leveraging the powerful natural language processing capabilities of LLMs to improve the accuracy and efficiency of searching and retrieving relevant information from vast amounts of text data. LLMs enable more intuitive and conversational interactions with search engines and enhance the overall user experience.
#
# Here are some key ways LLMs are used in Information Retrieval:
#
# 1. **Natural Language Queries:**
#    - LLMs allow users to express their information needs in a natural and conversational manner, rather than using traditional keyword-based search queries.
#    - This makes searching more intuitive and accessible, especially for users who may not be familiar with specific keywords or technical terms.
#
# 2. **Semantic Search:**
# ...

# %%
chat.history
# Out:
# [parts {
#    text: "What are the usecases for LLMs?"
#  }
#  role: "user",
#  parts {
# ...

# %%
for message in chat.history:
  display(Markdown(f'**{message.role}**: {message.parts[0].text}'))
# Out:
# **user**: What are the usecases for LLMs?
# **model**: 1. **Natural Language Processing (NLP):**
#    - Text Summarization: LLMs can create concise summaries of text documents, articles, or research papers, making it easier for users to quickly understand the key points.
#    - Machine Translation: LLMs can translate text from one language to another, enabling global communication and understanding.
#    - Question Answering: LLMs can answer questions about a wide range of topics, providing useful information to users in a conversational manner.
#    - Chatbots and Virtual Assistants: LLMs power chatbots and virtual assistants that can engage in natural language conversations with users, providing information, answering queries, and performing various tasks.
#
# 2. **Content Creation:**
#    - Creative Writing: LLMs can generate creative text, such as stories, poems, and scripts, demonstrating their ability to produce unique and engaging content.
# ...
